# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([10, 9, 2, 15, 10, 16, 11, 16])
y = np.array([95, 80, 10, 50, 45, 98, 38, 93])

# %%
sns.set_style('darkgrid')
sns.scatterplot(x = x, y = y)
plt.xlabel('Number of hours spent driving')
plt.ylabel('Risk Score')
plt.show()

# %%
def calculate_coefficents():
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    numerator = 0
    denominator = 0
    for i in range(len(x)):
        numerator += ((x[i]-x_mean)*(y[i]-y_mean))
        denominator += (x[i]-x_mean)**2
    B1 = numerator/denominator
    B0 = y_mean - (beta * x_mean)
    return B0, B1

# %%
B0, B1 = calculate_coefficents()
print("EQUATION OF BEST FIT LINE : ", B0, " + ", B1, "*x")
# Out:
# EQUATION OF BEST FIT LINE :  12.584627964022893  +  4.58789860997547 *x

# %%
def predict_y(x):
    return B0+(B1*x)

# %%
sns.set_style('darkgrid')
sns.scatterplot(x = x, y = y)
plt.xlabel('Number of hours spent driving')
plt.ylabel('Risk Score')
plt.plot(x, predict_y(x), color = "#6EBF8B")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
model = regressor.fit(x.reshape(-1, 1), y.reshape(-1, 1))

# %%
print("EQUATION OF BEST FIT LINE : ", model.intercept_[0], " + ", model.coef_[0][0], "* x")
# Out:
# EQUATION OF BEST FIT LINE :  12.584627964022907  +  4.587898609975469 * x

# %%
model.score(x.reshape(-1, 1), y.reshape(-1, 1))
# Out:
# 0.43709481451010035
